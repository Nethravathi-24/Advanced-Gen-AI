# %%
username = "admin"
password = "1234"

# Example input (you can replace with input())
input_username = "admin"
input_password = "1234"

if input_username == username and input_password == password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Login Successful
